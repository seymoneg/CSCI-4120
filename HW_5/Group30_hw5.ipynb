# %% [markdown]
# # Homework 5 RF Accuracy Improvement
#
# This assignment is inspired by examples of Shan-Hung Wu from National Tsing Hua University.
#
# Requirement: improve the accuracy per feature of the following code from 0.03 up to at least 0.40 and accuracy should be more than 0.92
#
# Here are three hints:
#
#     You can improve the ratio by picking out or "creating" several features.
#     Tune hyperparameters
#     The ratio can be improved from 0.03 up to 0.47.

# %% [markdown]
# Seymone Gugneja, Michael Trofimov

# %%
# You are required to classify breast cancer data using RandomForestClassifier.
# Build a classification model and Tune hyperparameters (e.g. criterion, n_estimators …).
# Your accuracy should be more than 0.92 and (Accuracy/number of features) should be more than 0.45.

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest

# load the breast_cancer dataset
#added as_frame=True to switch from an array to a dataframe to make it easier to work with
init_data = load_breast_cancer()
(X, y) = load_breast_cancer(return_X_y=True,as_frame=True) 
print(X.shape)
# Out:
# (569, 30)

# %%
# show sample of the dataset
X.sample(5)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 204        12.47         18.60           81.09      481.9          0.09965
# 70         18.94         21.31          123.60     1130.0          0.09009
# 131        15.46         19.48          101.70      748.9          0.10920
# 431        12.40         17.68           81.47      467.8          0.10540
# 540        11.54         14.44           74.65      402.9          0.09984
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 204            0.1058         0.08005              0.03821         0.1925
# 70             0.1029         0.10800              0.07951         0.1582
# 131            0.1223         0.14660              0.08087         0.1931
# 431            0.1316         0.07741              0.02799         0.1811
# 540            0.1120         0.06737              0.02594         0.1818
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 204                 0.06373  ...         14.97          24.64
# 70                  0.05461  ...         24.86          26.58
# 131                 0.05796  ...         19.26          26.00
# 431                 0.07102  ...         12.88          22.91
# 540                 0.06782  ...         12.26          19.68
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 204            96.05       677.9            0.1426             0.2378
# 70            165.90      1866.0            0.1193             0.2336
# 131           124.90      1156.0            0.1546             0.2394
# 431            89.61       515.8            0.1450             0.2629
# 540            78.78       457.8            0.1345             0.2118
#
#      worst concavity  worst concave points  worst symmetry  \
# 204           0.2671               0.10150          0.3014
# 70            0.2687               0.17890          0.2551
# 131           0.3791               0.15140          0.2837
# 431           0.2403               0.07370          0.2556
# 540           0.1797               0.06918          0.2329
#
#      worst fractal dimension
# 204                  0.08750
# 70                   0.06589
# 131                  0.08019
# 431                  0.09359
# 540                  0.08134
#
# [5 rows x 30 columns]

# %%
# split data into input and taget variable(s)
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# TODO Select some features (X), hint: based on the connections with
# our Y (importance? correlation?)
n_features = 2
k_best = SelectKBest(k=n_features)
x_train_new = k_best.fit_transform(x_train, y_train)
x_test_new = k_best.transform(x_test)

# %%
# TODO Tune parameters for RandomForestClassifier
rand_classifier = RandomForestClassifier(class_weight='balanced', random_state=0)

#define parameters for gridsearch
param_grid = {
    'n_estimators': [20,50,100,200],
    'min_samples_split': [2,4],
    'min_samples_leaf': [1,2,4],
    'criterion': ["gini", "entropy"],
}

# %%
# TODO need 5 fold cross validation
grid = GridSearchCV(rand_classifier, param_grid, verbose=2)
grid.fit(x_train_new, y_train)

print("Best parameters: ", grid.best_params_)

model = grid.best_estimator_
y_pred = model.predict(x_test_new)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=20; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.2s
# Best parameters:  {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}

# %%
# TODO Calculate Average accuracy score
acc = accuracy_score(y_test, y_pred)

# %%
# TODO Calculate Average (accuracy score/number of features)
acc_per_feature = acc / n_features

print("Accuracy: {}, per feature: {}".format(acc, acc_per_feature))
# Out:
# Accuracy: 0.956140350877193, per feature: 0.4780701754385965
